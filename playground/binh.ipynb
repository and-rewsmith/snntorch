# %%
import os
import sys
import torch
import torch.nn as nn
import time
import matplotlib.pyplot as plt
import pickle
from datetime import datetime


# Add local snntorch repository to Python's path
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.insert(0, module_path)

import snntorch as snn
from snntorch._neurons.stateleaky import StateLeaky
from snntorch._neurons.leaky import Leaky

# %matplotlib inline

# %%
# --- Setup ---
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f"Using device: {device}")

# --- Network Architecture Parameters ---
num_inputs = 784  # 28*28
num_hidden = 1000
num_outputs = 10
beta = 0.95 # For standard Leaky neuron

#==============================================================================
#  1. Network Definition for the new `StateLeaky` Neuron (No Time Loop)
#==============================================================================
class StateLeakyNet(nn.Module):
    """
    This network uses the convolutional `StateLeaky` neuron.
    It processes the entire time sequence in a single forward pass without a loop.
    """
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(num_inputs, num_hidden)
        self.lif1 = StateLeaky(beta=beta, channels=num_hidden, max_timesteps=1024)
        self.fc2 = nn.Linear(num_hidden, num_outputs)
        self.lif2 = StateLeaky(beta=beta, channels=num_outputs, max_timesteps=1024)

    def forward(self, x):
        cur1 = self.fc1(x)
        spk1, mem1 = self.lif1(cur1)
        cur2 = self.fc2(spk1)
        spk2, mem2 = self.lif2(cur2)
        return spk2, mem2

#==============================================================================
#  2. Network Definition for the standard `snn.Leaky` Neuron (With Time Loop)
#==============================================================================
class StandardLeakyNet(nn.Module):
    """
    This network uses the standard `snn.Leaky` neuron.
    It processes data one time step at a time using a classic for loop.
    """
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(num_inputs, num_hidden)
        self.lif1 = Leaky(beta=beta)
        self.fc2 = nn.Linear(num_hidden, num_outputs)
        self.lif2 = Leaky(beta=beta)

    def forward(self, x):
        mem1 = self.lif1.init_leaky()
        mem2 = self.lif2.init_leaky()
        spk2_rec = []
        mem2_rec = []
        for step in range(x.shape[0]):
            cur1 = self.fc1(x[step])
            spk1, mem1 = self.lif1(cur1, mem1)
            cur2 = self.fc2(spk1)
            spk2, mem2 = self.lif2(cur2, mem2)
            spk2_rec.append(spk2)
            mem2_rec.append(mem2)
        return torch.stack(spk2_rec, dim=0), torch.stack(mem2_rec, dim=0)


#==============================================================================
#  3. Benchmarking Functions
#==============================================================================
def get_peak_memory(device):
    """Gets the peak GPU memory usage in MB."""
    if device.type == 'cuda':
        return torch.cuda.max_memory_allocated(device) / 1024**2
    return 0

def test_inference_memory(network_class, device, batch_size=128, start_seq_len=50, step=50):
    """Tests memory and time during inference and returns results for plotting."""
    print(f"\n--- Starting INFERENCE Test for: {network_class.__name__} ---")
    net = network_class().to(device)
    net.eval()
    max_seq_len = getattr(net.lif1, 'max_timesteps', float('inf'))
    sequence_length = start_seq_len
    
    # Lists to store results
    seq_lens, peak_mems, exec_times = [], [], []

    while sequence_length <= max_seq_len:
        try:
            print(f"--> Testing Sequence Length: {sequence_length}")
            data = torch.rand(sequence_length, batch_size, num_inputs).to(device)
            
            if device.type == 'cuda':
                torch.cuda.reset_peak_memory_stats(device)
                torch.cuda.synchronize() # Wait for all previous GPU work to finish
            
            start_time = time.time()
            with torch.no_grad():
                spk_rec, mem_rec = net(data)
            end_time = time.time()
            
            if device.type == 'cuda':
                torch.cuda.synchronize() # Wait for the forward pass to complete
            
            duration = end_time - start_time
            peak_mem = get_peak_memory(device)
            print(f"Peak Memory: {peak_mem:.2f} MB | Execution Time: {duration:.4f} s")
            
            seq_lens.append(sequence_length)
            peak_mems.append(peak_mem)
            exec_times.append(duration)
            
            del data, spk_rec, mem_rec
            sequence_length += step
            time.sleep(0.1)

        except torch.cuda.OutOfMemoryError:
            print(f"\n💥 Out-of-Memory Error during INFERENCE at Sequence Length: {sequence_length}")
            return seq_lens, peak_mems, exec_times
        except KeyboardInterrupt:
            print("\nInference test stopped by user.")
            return seq_lens, peak_mems, exec_times
            
    print(f"\n✅ Inference test completed. Reached max sequence length: {int(max_seq_len)}")
    return seq_lens, peak_mems, exec_times


def test_training_memory(network_class, device, batch_size=128, start_seq_len=25, step=25):
    """Tests memory and time during training and returns results for plotting."""
    print(f"\n--- Starting TRAINING Test for: {network_class.__name__} ---")
    net = network_class().to(device)
    net.train()
    max_seq_len = getattr(net.lif1, 'max_timesteps', float('inf'))
    optimizer = torch.optim.Adam(net.parameters(), lr=1e-4)
    loss_fn = nn.CrossEntropyLoss()
    sequence_length = start_seq_len

    seq_lens, peak_mems, exec_times = [], [], []

    while sequence_length <= max_seq_len:
        try:
            print(f"--> Testing Sequence Length: {sequence_length}")
            data = torch.rand(sequence_length, batch_size, num_inputs).to(device)
            targets = torch.randint(0, num_outputs, (batch_size,)).to(device)

            if device.type == 'cuda':
                torch.cuda.reset_peak_memory_stats(device)
                torch.cuda.synchronize()

            start_time = time.time()
            spk_rec, _ = net(data)
            loss = loss_fn(spk_rec.sum(dim=0), targets)
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
            end_time = time.time()
            
            if device.type == 'cuda':
                torch.cuda.synchronize()

            duration = end_time - start_time
            peak_mem = get_peak_memory(device)
            print(f"Peak Memory: {peak_mem:.2f} MB | Execution Time: {duration:.4f} s")

            seq_lens.append(sequence_length)
            peak_mems.append(peak_mem)
            exec_times.append(duration)
            
            del data, targets, spk_rec, loss
            sequence_length += step
            time.sleep(0.1)

        except torch.cuda.OutOfMemoryError:
            print(f"\n💥 Out-of-Memory Error during TRAINING at Sequence Length: {sequence_length}")
            return seq_lens, peak_mems, exec_times
        except KeyboardInterrupt:
            print("\nTraining test stopped by user.")
            return seq_lens, peak_mems, exec_times
            
    print(f"\n✅ Training test completed. Reached max sequence length: {int(max_seq_len)}")
    return seq_lens, peak_mems, exec_times



#==============================================================================
#  4. Run Benchmarks
#==============================================================================

results = {}

# Run tests and store results
sl_inf_seq, sl_inf_mem, sl_inf_time = test_inference_memory(StateLeakyNet, device, batch_size=256)
results['state_leaky_inf'] = {'seq': sl_inf_seq, 'mem': sl_inf_mem, 'time': sl_inf_time}

sl_train_seq, sl_train_mem, sl_train_time = test_training_memory(StateLeakyNet, device, batch_size=256)
results['state_leaky_train'] = {'seq': sl_train_seq, 'mem': sl_train_mem, 'time': sl_train_time}

std_inf_seq, std_inf_mem, std_inf_time = test_inference_memory(StandardLeakyNet, device, batch_size=256)
results['standard_leaky_inf'] = {'seq': std_inf_seq, 'mem': std_inf_mem, 'time': std_inf_time}

std_train_seq, std_train_mem, std_train_time = test_training_memory(StandardLeakyNet, device, batch_size=256)
results['standard_leaky_train'] = {'seq': std_train_seq, 'mem': std_train_mem, 'time': std_train_time}

# Get the current time and format it into a string
timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

# Create the filename using an f-string
results_filename = f"benchmark_results_{timestamp}.pkl"

with open(results_filename, 'wb') as f:
    pickle.dump(results, f)

print(f"Generated filename: {results_filename}")
# Out:
# Using device: cuda
#
# --- Starting INFERENCE Test for: StateLeakyNet ---
# --> Testing Sequence Length: 50
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([50, 1000])
# 50
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([50, 10])
# 50
# 10
# Peak Memory: 347.72 MB | Execution Time: 0.0588 s
# --> Testing Sequence Length: 100
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([100, 1000])
# 100
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([100, 10])
# 100
# 10
# Peak Memory: 827.64 MB | Execution Time: 0.0008 s
# --> Testing Sequence Length: 150
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([150, 1000])
# 150
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([150, 10])
# 150
# 10
# Peak Memory: 1306.52 MB | Execution Time: 0.0008 s
# --> Testing Sequence Length: 200
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([200, 1000])
# 200
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([200, 10])
# 200
# 10
# Peak Memory: 1785.85 MB | Execution Time: 0.0008 s
# --> Testing Sequence Length: 250
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([250, 1000])
# 250
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([250, 10])
# 250
# 10
# Peak Memory: 2266.09 MB | Execution Time: 0.0008 s
# --> Testing Sequence Length: 300
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([300, 1000])
# 300
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([300, 10])
# 300
# 10
# Peak Memory: 2744.74 MB | Execution Time: 0.0009 s
# --> Testing Sequence Length: 350
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([350, 1000])
# 350
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([350, 10])
# 350
# 10
# Peak Memory: 3225.46 MB | Execution Time: 0.0009 s
# --> Testing Sequence Length: 400
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([400, 1000])
# 400
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([400, 10])
# 400
# 10
# Peak Memory: 3704.22 MB | Execution Time: 0.0009 s
# --> Testing Sequence Length: 450
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([450, 1000])
# 450
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([450, 10])
# 450
# 10
# Peak Memory: 4183.38 MB | Execution Time: 0.0008 s
# --> Testing Sequence Length: 500
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([500, 1000])
# 500
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([500, 10])
# 500
# 10
# Peak Memory: 4662.96 MB | Execution Time: 0.0007 s
# --> Testing Sequence Length: 550
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([550, 1000])
# 550
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([550, 10])
# 550
# 10
# Peak Memory: 5143.16 MB | Execution Time: 0.0008 s
# --> Testing Sequence Length: 600
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([600, 1000])
# 600
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([600, 10])
# 600
# 10
# Peak Memory: 5622.26 MB | Execution Time: 0.0008 s
# --> Testing Sequence Length: 650
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([650, 1000])
# 650
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([650, 10])
# 650
# 10
# Peak Memory: 6101.70 MB | Execution Time: 0.0008 s
# --> Testing Sequence Length: 700
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([700, 1000])
# 700
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([700, 10])
# 700
# 10
# Peak Memory: 6582.20 MB | Execution Time: 0.1281 s
# --> Testing Sequence Length: 750
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([750, 1000])
# 750
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([750, 10])
# 750
# 10
# Peak Memory: 7061.68 MB | Execution Time: 0.0013 s
# --> Testing Sequence Length: 800
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([800, 1000])
# 800
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([800, 10])
# 800
# 10
# Peak Memory: 7541.13 MB | Execution Time: 0.0008 s
# --> Testing Sequence Length: 850
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([850, 1000])
# 850
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([850, 10])
# 850
# 10
# Peak Memory: 8020.02 MB | Execution Time: 0.0014 s
# --> Testing Sequence Length: 900
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([900, 1000])
# 900
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([900, 10])
# 900
# 10
# Peak Memory: 8499.60 MB | Execution Time: 0.1388 s
# --> Testing Sequence Length: 950
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([950, 1000])
# 950
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([950, 10])
# 950
# 10
# Peak Memory: 8979.93 MB | Execution Time: 0.0017 s
# --> Testing Sequence Length: 1000
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([1000, 1000])
# 1000
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([1000, 10])
# 1000
# 10
# Peak Memory: 9459.03 MB | Execution Time: 0.0016 s
#
# ✅ Inference test completed. Reached max sequence length: 1024
#
# --- Starting TRAINING Test for: StateLeakyNet ---
# --> Testing Sequence Length: 25
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([25, 1000])
# 25
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([25, 10])
# 25
# 10
# Peak Memory: 3295.59 MB | Execution Time: 0.0618 s
# --> Testing Sequence Length: 50
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([50, 1000])
# 50
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([50, 10])
# 50
# 10
# Peak Memory: 3614.23 MB | Execution Time: 0.0016 s
# --> Testing Sequence Length: 75
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([75, 1000])
# 75
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([75, 10])
# 75
# 10
# Peak Memory: 3927.19 MB | Execution Time: 0.0015 s
# --> Testing Sequence Length: 100
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([100, 1000])
# 100
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([100, 10])
# 100
# 10
# Peak Memory: 4240.10 MB | Execution Time: 0.0015 s
# --> Testing Sequence Length: 125
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([125, 1000])
# 125
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([125, 10])
# 125
# 10
# Peak Memory: 4553.52 MB | Execution Time: 0.0019 s
# --> Testing Sequence Length: 150
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([150, 1000])
# 150
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([150, 10])
# 150
# 10
# Peak Memory: 4865.98 MB | Execution Time: 0.0018 s
# --> Testing Sequence Length: 175
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([175, 1000])
# 175
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([175, 10])
# 175
# 10
# Peak Memory: 5178.91 MB | Execution Time: 0.0015 s
# --> Testing Sequence Length: 200
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([200, 1000])
# 200
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([200, 10])
# 200
# 10
# Peak Memory: 5491.87 MB | Execution Time: 0.0017 s
# --> Testing Sequence Length: 225
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([225, 1000])
# 225
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([225, 10])
# 225
# 10
# Peak Memory: 5805.11 MB | Execution Time: 0.0017 s
# --> Testing Sequence Length: 250
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([250, 1000])
# 250
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([250, 10])
# 250
# 10
# Peak Memory: 6118.22 MB | Execution Time: 0.0016 s
# --> Testing Sequence Length: 275
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([275, 1000])
# 275
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([275, 10])
# 275
# 10
# Peak Memory: 6430.68 MB | Execution Time: 0.0015 s
# --> Testing Sequence Length: 300
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([300, 1000])
# 300
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([300, 10])
# 300
# 10
# Peak Memory: 6743.93 MB | Execution Time: 0.0016 s
# --> Testing Sequence Length: 325
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([325, 1000])
# 325
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([325, 10])
# 325
# 10
# Peak Memory: 7056.77 MB | Execution Time: 0.0017 s
# --> Testing Sequence Length: 350
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([350, 1000])
# 350
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([350, 10])
# 350
# 10
# Peak Memory: 7370.08 MB | Execution Time: 0.0016 s
# --> Testing Sequence Length: 375
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([375, 1000])
# 375
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([375, 10])
# 375
# 10
# Peak Memory: 7682.46 MB | Execution Time: 0.0016 s
# --> Testing Sequence Length: 400
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([400, 1000])
# 400
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([400, 10])
# 400
# 10
# Peak Memory: 7995.35 MB | Execution Time: 0.0016 s
# --> Testing Sequence Length: 425
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([425, 1000])
# 425
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([425, 10])
# 425
# 10
# Peak Memory: 8308.28 MB | Execution Time: 0.0016 s
# --> Testing Sequence Length: 450
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([450, 1000])
# 450
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([450, 10])
# 450
# 10
# Peak Memory: 8621.41 MB | Execution Time: 0.0017 s
# --> Testing Sequence Length: 475
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([475, 1000])
# 475
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([475, 10])
# 475
# 10
# Peak Memory: 8934.16 MB | Execution Time: 0.0016 s
# --> Testing Sequence Length: 500
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([500, 1000])
# 500
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([500, 10])
# 500
# 10
# Peak Memory: 9249.66 MB | Execution Time: 0.0016 s
# --> Testing Sequence Length: 525
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([525, 1000])
# 525
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([525, 10])
# 525
# 10
# Peak Memory: 9560.03 MB | Execution Time: 0.0018 s
# --> Testing Sequence Length: 550
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([550, 1000])
# 550
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([550, 10])
# 550
# 10
# Peak Memory: 9872.97 MB | Execution Time: 0.0015 s
# --> Testing Sequence Length: 575
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([575, 1000])
# 575
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([575, 10])
# 575
# 10
# Peak Memory: 10185.91 MB | Execution Time: 0.0017 s
# --> Testing Sequence Length: 600
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([600, 1000])
# 600
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([600, 10])
# 600
# 10
# Peak Memory: 10499.23 MB | Execution Time: 0.0018 s
# --> Testing Sequence Length: 625
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([625, 1000])
# 625
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([625, 10])
# 625
# 10
# Peak Memory: 10811.78 MB | Execution Time: 0.0017 s
# --> Testing Sequence Length: 650
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([650, 1000])
# 650
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([650, 10])
# 650
# 10
# Peak Memory: 11124.72 MB | Execution Time: 0.0018 s
# --> Testing Sequence Length: 675
# torch.Size([1024, 1000])
# ------------decay filter------------
# torch.Size([675, 1000])
# 675
# 1000
# torch.Size([1024, 10])
# ------------decay filter------------
# torch.Size([675, 10])
# 675
# 10
#
# 💥 Out-of-Memory Error during TRAINING at Sequence Length: 675
#
# --- Starting INFERENCE Test for: StandardLeakyNet ---
# --> Testing Sequence Length: 50
# Peak Memory: 7526.62 MB | Execution Time: 0.0202 s
# --> Testing Sequence Length: 100
# Peak Memory: 7565.87 MB | Execution Time: 0.0215 s
# --> Testing Sequence Length: 150
# Peak Memory: 7605.13 MB | Execution Time: 0.0324 s
# --> Testing Sequence Length: 200
# --> Testing Sequence Length: 3500
# Peak Memory: 10299.88 MB | Execution Time: 0.7450 s
# --> Testing Sequence Length: 3550
# Peak Memory: 10340.11 MB | Execution Time: 0.7556 s
# --> Testing Sequence Length: 3600
# Peak Memory: 10380.35 MB | Execution Time: 0.7729 s
# --> Testing Sequence Length: 3650
# Peak Memory: 10420.58 MB | Execution Time: 0.7825 s
# --> Testing Sequence Length: 3700
# Peak Memory: 10460.81 MB | Execution Time: 0.7950 s
# --> Testing Sequence Length: 3750
# Peak Memory: 10501.05 MB | Execution Time: 0.8472 s
# --> Testing Sequence Length: 3800
# Peak Memory: 10541.48 MB | Execution Time: 0.8072 s
# --> Testing Sequence Length: 3850
# Peak Memory: 10581.86 MB | Execution Time: 0.8929 s
# --> Testing Sequence Length: 3900
# Peak Memory: 10621.81 MB | Execution Time: 0.8325 s
# --> Testing Sequence Length: 3950
# Peak Memory: 10661.99 MB | Execution Time: 0.9243 s
# --> Testing Sequence Length: 4000
# Peak Memory: 10702.22 MB | Execution Time: 0.9275 s
# --> Testing Sequence Length: 4050
# Peak Memory: 10742.46 MB | Execution Time: 0.8620 s
# --> Testing Sequence Length: 4100
# Peak Memory: 10783.63 MB | Execution Time: 0.8779 s
# --> Testing Sequence Length: 4150
# Peak Memory: 10823.58 MB | Execution Time: 0.9519 s
# --> Testing Sequence Length: 4200
# Peak Memory: 10863.53 MB | Execution Time: 0.9623 s
# --> Testing Sequence Length: 4250
# Peak Memory: 10903.49 MB | Execution Time: 0.9134 s
# --> Testing Sequence Length: 4300
# Peak Memory: 10943.63 MB | Execution Time: 0.9186 s
# --> Testing Sequence Length: 4350
# Peak Memory: 10983.86 MB | Execution Time: 0.9292 s
# --> Testing Sequence Length: 4400
# Peak Memory: 11024.10 MB | Execution Time: 1.0019 s
# --> Testing Sequence Length: 4450
# Peak Memory: 11065.30 MB | Execution Time: 1.0188 s
# --> Testing Sequence Length: 4500
# Peak Memory: 11105.25 MB | Execution Time: 1.0784 s
# --> Testing Sequence Length: 4550
# Peak Memory: 11145.21 MB | Execution Time: 1.0627 s
# --> Testing Sequence Length: 4600
# Peak Memory: 11185.16 MB | Execution Time: 1.0615 s
# --> Testing Sequence Length: 4650
# Peak Memory: 11225.27 MB | Execution Time: 1.0737 s
# --> Testing Sequence Length: 4700
# Peak Memory: 11265.50 MB | Execution Time: 1.0864 s
# --> Testing Sequence Length: 4750
#
# 💥 Out-of-Memory Error during INFERENCE at Sequence Length: 4750
#
# --- Starting TRAINING Test for: StandardLeakyNet ---
# --> Testing Sequence Length: 25
# Peak Memory: 7558.92 MB | Execution Time: 0.0103 s
# --> Testing Sequence Length: 50
# Peak Memory: 7633.71 MB | Execution Time: 0.0521 s
# --> Testing Sequence Length: 75
# Peak Memory: 7702.43 MB | Execution Time: 0.0610 s
# --> Testing Sequence Length: 100
# Peak Memory: 7771.16 MB | Execution Time: 0.0395 s
# --> Testing Sequence Length: 125
# Peak Memory: 7839.89 MB | Execution Time: 0.0489 s
# --> Testing Sequence Length: 150
# Peak Memory: 7908.61 MB | Execution Time: 0.0579 s
# --> Testing Sequence Length: 175
# Peak Memory: 7977.99 MB | Execution Time: 0.0664 s
# --> Testing Sequence Length: 200
# Peak Memory: 8047.06 MB | Execution Time: 0.0758 s
# --> Testing Sequence Length: 225
# Peak Memory: 8116.03 MB | Execution Time: 0.0850 s
# --> Testing Sequence Length: 250
# Peak Memory: 8185.71 MB | Execution Time: 0.0960 s
# --> Testing Sequence Length: 275
# Peak Memory: 8254.94 MB | Execution Time: 0.1032 s
# --> Testing Sequence Length: 300

# %%
#==============================================================================
#  5. Plotting Function
#==============================================================================
def plot_results(results):
    """Generates plots comparing memory and time usage for different network types."""
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(18, 12))
    
    # --- Inference Memory Plot ---
    ax1.plot(results['state_leaky_inf']['seq'], results['state_leaky_inf']['mem'], 
             marker='o', linestyle='-', label='StateLeaky (Convolutional)')
    ax1.plot(results['standard_leaky_inf']['seq'], results['standard_leaky_inf']['mem'], 
             marker='x', linestyle='--', label='Standard Leaky (Recurrent)')
    ax1.set_title('Inference Memory Usage', fontsize=16)
    ax1.set_xlabel('Sequence Length', fontsize=12)
    ax1.set_ylabel('Peak Memory (MB)', fontsize=12)
    ax1.legend()
    ax1.grid(True, linestyle=':', alpha=0.6)

    # --- Training Memory Plot ---
    ax2.plot(results['state_leaky_train']['seq'], results['state_leaky_train']['mem'], 
             marker='o', linestyle='-', label='StateLeaky (Convolutional)')
    ax2.plot(results['standard_leaky_train']['seq'], results['standard_leaky_train']['mem'], 
             marker='x', linestyle='--', label='Standard Leaky (Recurrent)')
    ax2.set_title('Training Memory Usage', fontsize=16)
    ax2.set_xlabel('Sequence Length', fontsize=12)
    ax2.set_ylabel('Peak Memory (MB)', fontsize=12)
    ax2.legend()
    ax2.grid(True, linestyle=':', alpha=0.6)
    
    # --- Inference Time Plot ---
    ax3.plot(results['state_leaky_inf']['seq'], results['state_leaky_inf']['time'], 
             marker='o', linestyle='-', label='StateLeaky (Convolutional)')
    ax3.plot(results['standard_leaky_inf']['seq'], results['standard_leaky_inf']['time'], 
             marker='x', linestyle='--', label='Standard Leaky (Recurrent)')
    ax3.set_title('Inference Execution Time', fontsize=16)
    ax3.set_xlabel('Sequence Length', fontsize=12)
    ax3.set_ylabel('Time (seconds)', fontsize=12)
    ax3.legend()
    ax3.grid(True, linestyle=':', alpha=0.6)

    # --- Training Time Plot ---
    ax4.plot(results['state_leaky_train']['seq'], results['state_leaky_train']['time'], 
             marker='o', linestyle='-', label='StateLeaky (Convolutional)')
    ax4.plot(results['standard_leaky_train']['seq'], results['standard_leaky_train']['time'], 
             marker='x', linestyle='--', label='Standard Leaky (Recurrent)')
    ax4.set_title('Training Execution Time', fontsize=16)
    ax4.set_xlabel('Sequence Length', fontsize=12)
    ax4.set_ylabel('Time (seconds)', fontsize=12)
    ax4.legend()
    ax4.grid(True, linestyle=':', alpha=0.6)
    
    fig.suptitle('Performance Benchmark: StateLeaky vs. Standard Leaky Neuron', fontsize=20)
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    plt.show()

# %%
with open(results_filename, 'rb') as f:
    loaded_results = pickle.load(f)

if any(res['seq'] for res in loaded_results.values()):
    plot_results(loaded_results)
